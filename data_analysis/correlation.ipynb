# %% [markdown]
# ## Which features are correlated to each other?

# %% [markdown]
# ### 1. Connect to HopsWorks

# %%
import hopsworks, os
project = hopsworks.login(api_key_value=os.getenv("API_KEY"))
fs = project.get_feature_store()
fg = fs.get_or_create_feature_group("aqi_feature_pipeline", version=1)
df = fg.read()
# Out:
# 2025-11-09 17:32:08,373 INFO: Initializing external client
# 2025-11-09 17:32:08,374 INFO: Base URL: https://c.app.hopsworks.ai:443
# ...
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-09 17:32:11,076 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1248425
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.89s)

# %% [markdown]
# ### 2. Find correlations

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(15, 15))
seaborn.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Weather Data and Air Pollutants")
plt.show()
